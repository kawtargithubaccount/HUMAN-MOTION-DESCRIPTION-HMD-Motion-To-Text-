# %% [markdown]
# # final

# %%
pip install git+https://github.com/openai/CLIP.git
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-rgrws3ni
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-rgrws3ni
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (24.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (2.5.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from clip==1.0) (0.20.1+cu121)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from ftfy->clip==1.0) (0.2.13)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->clip==1.0) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->clip==1.0) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->torchvision->clip==1.0) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision->clip==1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->torchvision->clip==1.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->torchvision->clip==1.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->torchvision->clip==1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->torchvision->clip==1.0) (2024.2.0)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.3 MB/s eta 0:00:00
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369489 sha256=8caea93407e14b792007b8bf2cbc3c5aa4dc20155f430be14832f6d07786e2c9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sxj48t_k/wheels/da/2b/4c/d6691fa9597aac8bb85d2ac13b112deb897d5b50f5ad9a37e4
# Successfully built clip
# Installing collected packages: ftfy, clip
# Successfully installed clip-1.0 ftfy-6.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import clip
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# 🔹 Chemins des fichiers
DATA_PATH = "/kaggle/input/human-motion-description-hmd-motion-to-text"
MOTIONS_PATH = os.path.join(DATA_PATH, "motions")
TEXTS_PATH = os.path.join(DATA_PATH, "texts")
train_file = os.path.join(DATA_PATH, "train.txt")
test_file = os.path.join(DATA_PATH, "test.txt")

# 🔹 Chargement des IDs
print("🔄 Chargement des IDs...")
train_ids = [line.strip() for line in open(train_file).readlines()]
test_ids = [line.strip() for line in open(test_file).readlines()]
print("✅ Chargement des IDs terminé !")

# 🔹 Chargement du modèle CLIP
print("🔄 Chargement du modèle CLIP...")
device = "cuda" if torch.cuda.is_available() else "cpu"
clip_model, _ = clip.load("ViT-B/32", device=device)
clip_model.eval()
print("✅ CLIP chargé avec succès !")

# 🔹 Chargement du modèle GPT-2
print("🔄 Chargement du modèle GPT-2...")
gpt_tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
gpt_tokenizer.pad_token = gpt_tokenizer.eos_token  # Ajout du token de padding
gpt_model = GPT2LMHeadModel.from_pretrained("gpt2").to(device)
print("✅ GPT-2 chargé avec succès !")

# 🔹 Fonction pour générer les embeddings texte avec CLIP
def get_text_embedding(text):
    tokenized_text = clip.tokenize([text[:75]]).to(device)
    with torch.no_grad():
        text_embedding = clip_model.encode_text(tokenized_text)
        return text_embedding.float() / text_embedding.norm(dim=-1, keepdim=True)

# 🔹 Dataset Motion + Text Embeddings
class MotionTextDataset(Dataset):
    def __init__(self, motion_ids):
        self.motion_ids = motion_ids

    def __len__(self):
        return len(self.motion_ids)

    def __getitem__(self, idx):
        motion_id = self.motion_ids[idx]
        motion = np.load(os.path.join(MOTIONS_PATH, f"{motion_id}.npy"))
        motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), dtype=torch.float32)
        
        text_file = os.path.join(TEXTS_PATH, f"{motion_id}.txt")
        text = np.random.choice(open(text_file).readlines()).strip() if os.path.exists(text_file) else "No description available"
        text_embedding = get_text_embedding(text).squeeze()
        
        return motion_tensor, text_embedding, text

# 🔹 DataLoader
train_loader = DataLoader(MotionTextDataset(train_ids), batch_size=16, shuffle=True)

# 🔹 Encodeur basé sur LSTM
class MotionEncoder(nn.Module):
    def __init__(self, input_size, hidden_size, latent_dim):
        super(MotionEncoder, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, latent_dim)

    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        hidden = torch.cat((hidden[-2, :, :], hidden[-1, :, :]), dim=1)
        return self.fc(hidden)

# 🔹 Initialisation du modèle
encoder = MotionEncoder(input_size=66, hidden_size=128, latent_dim=512).to(device)
optimizer = optim.AdamW(encoder.parameters(), lr=1e-4)
criterion = nn.MSELoss()
num_epochs = 3

# 🔹 Entraînement de l'encodeur
print("🚀 Début de l'entraînement...")
for epoch in range(num_epochs):
    total_loss = 0
    progress_bar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}")
    for motion, text_embedding, _ in progress_bar:
        motion, text_embedding = motion.to(device), text_embedding.to(device)
        optimizer.zero_grad()
        z_motion = encoder(motion)
        loss = criterion(z_motion, text_embedding)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        progress_bar.set_postfix(loss=total_loss / (progress_bar.n + 1))
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss / len(train_loader)}")
print("✅ Entraînement terminé !")

# 🔹 Sauvegarde du modèle
torch.save(encoder.state_dict(), "motion_encoder.pth")
print("✅ Encodeur sauvegardé avec succès !")
# Out:
# 🔄 Chargement des IDs...
# ✅ Chargement des IDs terminé !
# 🔄 Chargement du modèle CLIP...
# 100%|███████████████████████████████████████| 338M/338M [00:23<00:00, 15.1MiB/s]
# ✅ CLIP chargé avec succès !
# 🔄 Chargement du modèle GPT-2...
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ✅ GPT-2 chargé avec succès !
# 🚀 Début de l'entraînement...
# Epoch 1/3: 100%|██████████| 814/814 [04:49<00:00,  2.81it/s, loss=0.000693]
# Epoch 1/3, Loss: 0.0006930335275102315
# Epoch 2/3: 100%|██████████| 814/814 [02:15<00:00,  6.00it/s, loss=0.000378]
# Epoch 2/3, Loss: 0.00037780532630415594
# Epoch 3/3: 100%|██████████| 814/814 [02:16<00:00,  5.95it/s, loss=0.000362]
# Epoch 3/3, Loss: 0.00036236785227233766
# ✅ Entraînement terminé !
# ✅ Encodeur sauvegardé avec succès !

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import GPT2Tokenizer  # On utilisera le tokenizer de GPT-2 pour le vocabulaire

device = "cuda" if torch.cuda.is_available() else "cpu"

# ------------------------------------------------------------
# Chemins des fichiers
# ------------------------------------------------------------
DATA_PATH = "/kaggle/input/human-motion-description-hmd-motion-to-text"
MOTIONS_PATH = os.path.join(DATA_PATH, "motions")
TEXTS_PATH = os.path.join(DATA_PATH, "texts")
train_file = os.path.join(DATA_PATH, "train.txt")
test_file = os.path.join(DATA_PATH, "test.txt")

with open(train_file, "r") as f:
    train_ids = [line.strip() for line in f.readlines()]
with open(test_file, "r") as f:
    test_ids = [line.strip() for line in f.readlines()]

# ------------------------------------------------------------
# Utilisation du tokenizer de GPT-2 (pour le vocabulaire)
# ------------------------------------------------------------
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
# On s'assure d'avoir un token de padding. Par défaut GPT-2 n'en possède pas.
tokenizer.pad_token = tokenizer.eos_token

# ------------------------------------------------------------
# Dataset pour le décodeur
# Pour chaque motion, on charge la motion (.npy) et le texte associé (ex: "000009.txt")
# On prend la première ligne du texte (avant un éventuel '#' si présent)
# On prépare les inputs pour le teacher forcing en décalant d'un token.
# ------------------------------------------------------------
class MotionTextDecoderDataset(Dataset):
    def __init__(self, motion_ids, motions_path, texts_path, tokenizer, max_length=64):
        self.motion_ids = motion_ids
        self.motions_path = motions_path
        self.texts_path = texts_path
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.motion_ids)
    
    def __getitem__(self, idx):
        motion_id = self.motion_ids[idx]
        # Charger la motion
        motion_path = os.path.join(self.motions_path, f"{motion_id}.npy")
        motion = np.load(motion_path)
        motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), dtype=torch.float32)
        
        # Charger le texte associé
        text_path = os.path.join(self.texts_path, f"{motion_id}.txt")
        if os.path.exists(text_path):
            with open(text_path, encoding="utf-8") as f:
                line = f.readline().strip()
            # Si le texte contient plusieurs descriptions séparées par '#', on prend la première
            text = line.split('#')[0].strip()
        else:
            text = "No description available"
        
        # Tokenisation
        encoding = self.tokenizer(text, truncation=True, max_length=self.max_length,
                                  padding="max_length", return_tensors="pt")
        input_ids = encoding["input_ids"].squeeze(0)  # séquence de tokens (longueur max_length)
        # Pour le teacher forcing, on décalle : 
        # On utilise input_ids[:-1] comme entrée et input_ids[1:] comme cible.
        decoder_input_ids = input_ids[:-1]
        target_ids = input_ids[1:]
        
        return motion_tensor, decoder_input_ids, target_ids

# ------------------------------------------------------------
# Définition de l'encodeur (le même que vous avez entraîné)
# ------------------------------------------------------------
class MotionEncoder(nn.Module):
    def __init__(self, input_size, hidden_size, latent_dim):
        super(MotionEncoder, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_size * 2, latent_dim)
    
    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        hidden = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        return self.fc(hidden)

encoder = MotionEncoder(input_size=66, hidden_size=128, latent_dim=512).to(device)
encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
encoder.eval()
# On gèle l'encodeur pour l'entraînement du décodeur
for param in encoder.parameters():
    param.requires_grad = False

# ------------------------------------------------------------
# Définition du décodeur LSTM
# ------------------------------------------------------------
class LSTMDecoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_layers=1):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)
    
    def forward(self, input_ids, hidden):
        # input_ids : (B, T)
        embeds = self.embedding(input_ids)  # (B, T, embed_dim)
        outputs, hidden = self.lstm(embeds, hidden)  # outputs : (B, T, hidden_dim)
        logits = self.fc(outputs)  # (B, T, vocab_size)
        return logits, hidden

# ------------------------------------------------------------
# Modèle complet : l'encodeur (gelé) + le décodeur LSTM
# On initialise l'état caché du décodeur à partir de l'embedding de motion.
# ------------------------------------------------------------
class MotionToTextDecoder(nn.Module):
    def __init__(self, encoder, decoder, latent_dim, hidden_dim):
        super(MotionToTextDecoder, self).__init__()
        self.encoder = encoder  # Gelé
        self.decoder = decoder
        # Projection de l'embedding latent vers l'état initial du LSTM (hidden state)
        self.latent_to_hidden = nn.Linear(latent_dim, hidden_dim)
    
    def forward(self, motion, decoder_input_ids):
        batch_size = motion.size(0)
        latent = self.encoder(motion)  # (B, latent_dim)
        # Initialisation de l'état caché et de la cellule
        h0 = self.latent_to_hidden(latent).unsqueeze(0)  # (1, B, hidden_dim)
        c0 = torch.zeros_like(h0)  # (1, B, hidden_dim)
        hidden = (h0, c0)
        logits, _ = self.decoder(decoder_input_ids, hidden)  # (B, T, vocab_size)
        return logits

vocab_size = len(tokenizer)
embed_dim = 512
hidden_dim = 512
decoder = LSTMDecoder(vocab_size, embed_dim, hidden_dim, num_layers=1).to(device)
model_decoder = MotionToTextDecoder(encoder, decoder, latent_dim=512, hidden_dim=hidden_dim).to(device)

# ------------------------------------------------------------
# Création du dataset et DataLoader pour l'entraînement du décodeur
# ------------------------------------------------------------
train_dataset_decoder = MotionTextDecoderDataset(train_ids, MOTIONS_PATH, TEXTS_PATH, tokenizer, max_length=64)
train_loader_decoder = DataLoader(train_dataset_decoder, batch_size=16, shuffle=True)

# ------------------------------------------------------------
# Entraînement du décodeur
# ------------------------------------------------------------
optimizer_decoder = optim.AdamW(model_decoder.parameters(), lr=1e-4)
criterion_decoder = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
num_epochs_decoder = 60

print("🚀 Début de l'entraînement du décodeur...")
model_decoder.train()
for epoch in range(num_epochs_decoder):
    total_loss = 0
    pbar = tqdm(train_loader_decoder, desc=f"Epoch {epoch+1}/{num_epochs_decoder}")
    for motion, decoder_input_ids, target_ids in pbar:
        motion = motion.to(device)
        decoder_input_ids = decoder_input_ids.to(device)
        target_ids = target_ids.to(device)
        
        optimizer_decoder.zero_grad()
        logits = model_decoder(motion, decoder_input_ids)  # (B, T, vocab_size)
        loss = criterion_decoder(logits.view(-1, vocab_size), target_ids.view(-1))
        loss.backward()
        optimizer_decoder.step()
        
        total_loss += loss.item()
        pbar.set_postfix(loss=f"{total_loss/(pbar.n+1):.4f}")
    print(f"Epoch {epoch+1}/{num_epochs_decoder}, Loss: {total_loss/len(train_loader_decoder):.4f}")
print("✅ Fin de l'entraînement du décodeur!")

# ------------------------------------------------------------
# Fonction d'inférence pour générer une phrase à partir d'une motion donnée
# ------------------------------------------------------------
def generate_sentence_decoder(model, motion_id, max_len=128):
    model.eval()
    # Charger la motion
    motion = np.load(os.path.join(MOTIONS_PATH, f"{motion_id}.npy"))
    motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), dtype=torch.float32).unsqueeze(0).to(device)
    with torch.no_grad():
        latent = model.encoder(motion_tensor)  # (1, 512)
        h0 = model.latent_to_hidden(latent).unsqueeze(0)  # (1, 1, hidden_dim)
        c0 = torch.zeros_like(h0)
        hidden = (h0, c0)
    
    # Initialiser avec un token de départ.
    # Si le tokenizer dispose d'un token BOS, on l'utilise, sinon on utilise EOS.
    start_token = tokenizer.bos_token_id if tokenizer.bos_token_id is not None else tokenizer.eos_token_id
    input_token = torch.tensor([[start_token]], device=device)
    generated_tokens = [start_token]
    
    # Génération token par token
    for _ in range(max_len):
        with torch.no_grad():
            embeds = model.decoder.embedding(input_token)  # (1, 1, embed_dim)
            output, hidden = model.decoder.lstm(embeds, hidden)  # (1, 1, hidden_dim)
            logits = model.decoder.fc(output.squeeze(1))  # (1, vocab_size)
            next_token = torch.argmax(logits, dim=-1).unsqueeze(0)  # (1, 1) - Greedy search
            token_id = next_token.item()
            if token_id == tokenizer.eos_token_id:
                break
            generated_tokens.append(token_id)
            input_token = next_token
    sentence = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    return sentence

# ------------------------------------------------------------
# Exemple d'inférence sur une motion du test set
# ------------------------------------------------------------
motion_id_example = test_ids[0]  # Par exemple, "000009"
sentence_generated = generate_sentence_decoder(model_decoder, motion_id_example, max_len=30)
print(f"Motion {motion_id_example} -> {sentence_generated}")
# Out:
# <ipython-input-3-803f2ea2f092>:93: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
# 🚀 Début de l'entraînement du décodeur...
# Epoch 1/60: 100%|██████████| 814/814 [01:01<00:00, 13.14it/s, loss=5.2163]
# Epoch 1/60, Loss: 5.2163
# Epoch 2/60: 100%|██████████| 814/814 [01:00<00:00, 13.45it/s, loss=3.9945]
# Epoch 2/60, Loss: 3.9896
# Epoch 3/60: 100%|██████████| 814/814 [00:59<00:00, 13.74it/s, loss=3.6808]
# Epoch 3/60, Loss: 3.6763
# Epoch 4/60: 100%|██████████| 814/814 [00:59<00:00, 13.69it/s, loss=3.4708]
# Epoch 4/60, Loss: 3.4665
# Epoch 5/60: 100%|██████████| 814/814 [00:59<00:00, 13.76it/s, loss=3.3077]
# Epoch 5/60, Loss: 3.3036
# Epoch 6/60: 100%|██████████| 814/814 [00:58<00:00, 13.85it/s, loss=3.1646]
# Epoch 6/60, Loss: 3.1607
# Epoch 7/60: 100%|██████████| 814/814 [00:58<00:00, 13.99it/s, loss=3.0345]
# Epoch 7/60, Loss: 3.0308
# Epoch 8/60: 100%|██████████| 814/814 [01:00<00:00, 13.44it/s, loss=2.9189]
# Epoch 8/60, Loss: 2.9153
# Epoch 9/60: 100%|██████████| 814/814 [01:03<00:00, 12.77it/s, loss=2.8159]
# Epoch 54/60: 100%|██████████| 814/814 [00:59<00:00, 13.71it/s, loss=0.7551]
# Epoch 54/60, Loss: 0.7542
# Epoch 55/60: 100%|██████████| 814/814 [00:59<00:00, 13.74it/s, loss=0.7410]
# Epoch 55/60, Loss: 0.7401
# Epoch 56/60: 100%|██████████| 814/814 [00:58<00:00, 13.84it/s, loss=0.7302]
# Epoch 56/60, Loss: 0.7293
# Epoch 57/60: 100%|██████████| 814/814 [00:58<00:00, 13.83it/s, loss=0.7199]
# Epoch 57/60, Loss: 0.7190
# Epoch 58/60: 100%|██████████| 814/814 [00:58<00:00, 13.89it/s, loss=0.7078]
# Epoch 58/60, Loss: 0.7069
# Epoch 59/60: 100%|██████████| 814/814 [00:59<00:00, 13.67it/s, loss=0.6960]
# Epoch 59/60, Loss: 0.6951
# Epoch 60/60: 100%|██████████| 814/814 [00:59<00:00, 13.77it/s, loss=0.6860]
# Epoch 60/60, Loss: 0.6852
# ✅ Fin de l'entraînement du décodeur!
# Motion 014295 ->  on the leg and start moving. they bring hands up and down while holding the legs apart. they then stand back up and down facing forward.

# %%
# 🔹 Chargement du modèle sauvegardé (optionnel, si vous partez d'une nouvelle session)
encoder = MotionEncoder(input_size=66, hidden_size=128, latent_dim=512).to(device)
encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
encoder.eval()  # Mode évaluation

# 🔹 Préparation du DataLoader pour l'ensemble de test
test_dataset = MotionTextDataset(test_ids)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# 🔹 Boucle de test
total_test_loss = 0.0
criterion = nn.MSELoss()

with torch.no_grad():
    for motion, text_embedding, text in tqdm(test_loader, desc="Test"):
        motion, text_embedding = motion.to(device), text_embedding.to(device)
        predicted_embedding = encoder(motion)
        loss = criterion(predicted_embedding, text_embedding)
        total_test_loss += loss.item()

avg_test_loss = total_test_loss / len(test_loader)
print(f"Test Loss moyenne : {avg_test_loss:.4f}")
# Out:
# <ipython-input-4-ef8b41dfd7c8>:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
# Test: 100%|██████████| 63/63 [00:14<00:00,  4.28it/s]
# Test Loss moyenne : 0.0005

# %%
import pandas as pd

# Mettez le modèle en mode évaluation
model_decoder.eval()

results = []
# Parcourir toutes les motions du test
for motion_id in test_ids:
    sentence = generate_sentence_decoder(model_decoder, motion_id, max_len=10)
    results.append({"id": motion_id, "text": sentence})
     # Optionnel : affiche chaque résultat

# Création du DataFrame et sauvegarde en CSV
submission = pd.DataFrame(results)
submission.to_csv("submissionv3.csv", index=False)

# %%
pd.read_csv("submission.csv")['text'].unique()
# Out:
# array([' on the leg and start moving. they bring hands up and down while holding the legs apart. they then stand back up and down facing forward.  he walks in a complete position before taking a circle back in the way he started to walk back a few times. he turns to the left and walks',
#        ' is on the floor and crossing their legs. they are doing the handrail to walk back and forth. then the figure is walking back and forth. the figure turns and turns to the front. then they step back the opposite end of the plane. they are doing the air and turns and takes 3',
#        ' the hands and band the legs to the legs. the person is walking and then backwards to the side. then they stop running, stop hands and put something down from behind them and then to stop. he looks like someone else is in fighting but and then they do running and then running from back to',
#        ' walks from top left towards bottom right, backtracks, walks forward to the left and backtracks to the left. then walks forward again and stops.  turns while walking forward again. then turns around 180 degrees and walks back to the right.  he turns around and walks back to the original spot',
#        ' walks from right to left in a zig zag line. the person is walking to the right. they then stop running and turn to the left and then step back to the right.  then takes a step and turns to the right and repeats the step. they then stop walking and the walk',
#        ' arm in a position, then outstretched arms, then shifts right arm to head then back. appears to be cleaning an object like motion of a car. the left arm extends at the left shoulder.  the right hand is holding the head in a chair and the right hand. he is holding the',
#        ' walks from right to left in a zig zag line. the person is on to the side then stands and jogs to the other side, before turning to the right and back. he is jogging again. then they stop to walk back and forth from the ground while walking forward. they',
#        ' walks from top left towards bottom right, backtracks, walks forward to the left and backtracks to the left. then walks forward again.  turns and walks back. the person steps to the right.  he walks forward and turns to the right and continues. he washes a bit. then',
#        ' arms are brought down to the right and played. he then puts arms back at shoulder level.  he then raises both arms straight out to the side. he then raises his arms to shoulder level again, then drops both arms straight out to the sides.  then raises both arms again and then raises',
#        ' is walking on a treadmill with arms outstretched. they step forward with hands straight outstretched. they then raise both arms to wave them and upwards. finally they move both arms down to the side.  he then left hand moves arms and body slightly forward.  he then turns left foot to the',
#        ' arms are brought down to the chest then drops left foot. person walks to the right in a circle.  he turns around to the left hand on the way back. they then turn to the right and keeps walking., the same way of the way they came. they then turn from about. they',
#        ' arms are brought down to the right and played, then puts arms back and forth. he turns to the left and then the goes again to the right.  after taking four steps and the left hand on the right hand.  the person then goes back to original spot. he then lowers to a',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns left while walking. the person turns around and walks back.  he turns to the right and continues to walk. the person then turns to the right and continues on the same spot. they',
#        ' is on the floor, holding up and hands on the side of head. the person is holding it in and then stands. he walks forward again.  he turns around, walks down, sits down, stands back up. they then turn around and walk away. the person turns around and walks.',
#        " arm out, appears to be cleaning it's hand holding head and arms then moving arms. then drops one leg back to front. he then drops both arms down to sides. he then drops arms to sides.  he then drops arms down to the sides. he then lowers his arms straight out to",
#        ' walks up stairs with a limp. the person walks forward, then turns around the walks in the opposite direction. they then turn right and repeat the same motion. then they turn right and go back to the left again. they stop from right to left. the person then walks forward for a few steps',
#        ' walks from top left towards bottom, up and back down to the right. he walks back to the right.  he walks forward, then turns around and walks back the way. he turns and walks back to the start position. he then turns the walks back and sits down. the person then gets',
#        ' is walking on a treadmill with arms outstretched. they walk the straight forward and turns. the body is slightly to the right.then they are running forward and is pushed back, they are walking, they step about the right foot, and then a few steps to their left. they stop and take',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. while holding the rail with his right hand. they then turn to the left and put something down. they then stop, and finally takes a step or motion. the figure walks forward and turns to the right hand',
#        ' is on the floor, holding up and moving arms in side to side and moving it back. he drops them to the sides. he then drops his arms to shoulder level. they then drops them down while they are doing arm circles. the left arm reaches down with each hand and straightens up.',
#        ' walks from top left towards bottom, backtracks, walks forward a few steps and stops. he walks back to the original position. then turns around and walks back to the starting point. the figure walks back to the right. then turns around and jogs to the right. they then turn to their',
#        ' walks from top to bottom, up a couple of the steps and takes a couple more steps. he then walks back and stops. the person turns back and walks forward. they then stop on the same spot. they then turn around and walk back to the original spot. they are going back together.',
#        ' is walking on a treadmill with arms outstretched. they walk the straight forward and turns. the body is slightly bent backwards. the person is walking and ends of the stairs. he then turns and takes a step and steps back the opposite direction.  he turns and steps forward again and stops. he',
#        ' up with his arms elevated, head down and foot in a straight line, he turns to right and then goes back to step forward, then straightens out to the left and turns slightly to the right, then jogs to the left, then stops, turns and walks back to the right. he',
#        ' walks from top left towards bottom, backtracks, walks forward a few steps and stops. he walks back to the original position. then the person turns to the right side. he then walks backwards the other way. he turns 180 degrees to the left and walks back the other way. he turns around',
#        ' walks forward, turns to the right and walks. the person then walks back and turns the goes to the original position. then they turn around and walk to the left. then stop again to the right turn around. then they stop on the hands and make a square motion as they walk back to their',
#        ' arm in a position, then throw right arm out, then buttons like excercising then moving arms and right. then left shoulder. arms then crosses both arms. appears to be moving forward.  he then lifts both arms straight outstretched in front of him. then drops arms down, shoulder',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns left while walking. the person turns around and walks back. the steps to the left.  he then turns around and walks back.  the steps again.  he turns around and walks',
#        ' arm out, drop right arm extends aggressively back, then a bend at the knee and waist. person is doing arm circles. then left arm is jerks. he drops arms at the elbow, drops them to his sides. then they stop the person is doing arm circles. they stop after and make',
#        ' on the leg and start moving the body. and the person is walking and then back and forth. they step on their feet and feet shoulder width. but they are holding onto a handrail. they walk back. they then raise arms and shake hands up. they stop, and prepare forward to catch',
#        ' arm in a position, then twists leg, then twists to the right and then the left. the arms are straight out. the person then goes back to the left and the left hand to the right and then left hand extends the right hand and then the left hand extends right hand then the right and',
#        ' walks from right to left in a zig zag pattern. the person is side to side. the person is walking to the right. they then stop to take something and then they do the same motion with their left arm and then continues to walk the other way. they stop again and turn around',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. while holding the rail with his right hand. they then turn to the left and put something down. they then stop, and finally takes a step or motion. the figure takes three steps and stops. he turns',
#        ' arms are brought down to the left and played. he then puts arms back down. he then lowers his arms straight out to the sides and straightens out and straightens out and turns to his right a few steps. then he walks in a counterclockwise circle. he sits, then stands still',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns around and walks back. the steps back. he is holding the object. he then walks back to the start position. he then turns around and walks a back of the way. he sits',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. they step on their right foot. they then turn to their left and walks back to the right. they stop again and walk to the left. then they stop again and walk forward to the right and stops and',
#        ' arms are brought down to the left and played. he then puts both arms back down to the ground. he then drops both arms straight out to the sides, drops his right arm, then steps down the stairs and raises both arms. he then walks back to the left.  he then stops before',
#        ' on the leg and moving the hands in a position as if the motion of some thing on the floor. their hands are held out, the person is held at the air and then claps again. they then stop to a stop. they are running in a jump forward. they are doing a hand',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns right again. then turns around again and walks back. the steps turns. he then turns around and walks the opposite direction in a circle.  he then turns 180 degrees and walks the opposite',
#        ' on the leg and start moving. the person is doing a hand gesture. then they walk back towards their original spot. they raise their hands are straight out to their sides. they then raise both hands and at the chest, imitating a teapot. their hands drop to their knees and are',
#        ' arms are brought down to the chest then drops left foot. appears to be hands in no hurry at.  he then stops and turns to the left hand side before standing still. he reaches out with his right hand to grasp something nearby at the same time. he then lowers it to its side and',
#        ' walks from top left towards bottom, backtracks, walks forward a few steps and stops. he walks back to the original position. then the person turns to the right side.  then turns to the left and keeps walking again. the person turns to his right then turns to his right again. then',
#        ' is on the floor and crossing their legs. they are walking up and down on the floor. they walk up straight and then turn around again. the person is walking back, and then turns around. they walk back again. they walk six steps and turns their torso. they walk back to the original',
#        ' arm in a position, then outstretched arms and down to motion. then the right arm goes to the left, and swings right arms. then goes back to the left direction.  left then right arms straight out and the flailing to the ground. arms straight out to the sides and the left',
#        ' walks from top left towards bottom, backtracks, walks forward a few steps and stops. he walks back to the original position. then the person turns to the right hand side steps.  the person turns to the left and walks back to the original position. the person then turns to the left 180',
#        ' walks from top left to bottom right, and then up the stairs arms down. they are straight down the straight and the left.  the person then goes back to original spot. then they stand back up and walking to their left. the left hand extends to the right. then the person then takes',
#        ' arms are brought down to the right and played. he then puts arms back down. he then lowers his arms straight out to the sides and straightens out and straightens out and walks forward. he then walks forward, stops, turns his body to the right and sits down. he then gets his',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. while holding the rail with his right hand. they then turn to the left and put something down. they then stop, and finally takes a step up with the railing. they step and their right foot. they',
#        ' walks from top left to bottom right, up and down off the ground, and back up to the left and repeats. the person is walking. he is holding onto the knee of the table. then they step back, before setting the object back down to their left. they then raise both hands to',
#        ' walks from top left towards bottom right, backtracks, walks forward to the left and backtracks to the left. then walks forward again and stops.  turns while walking forward again.  he turns around and walks back in a counterclockwise circle. he sits, and then stands back up.',
#        ' on the leg and start moving the hands. and the start moving in and stopped. then again like excercising flapping. arms and drops arms. they are walking forward in circles. they raise and hands are in the air appearing to be standing. they move their left arm and move both',
#        ' arm in a position, then twists leg and right leg inward and then outward. then the person is standing still. the person is slightly bent with both arms. they then drops both arms to the sides. then drops both arms straight out to the sides. he drops both hands to the side of the',
#        ' is on the floor, holding up and arms in front of him while standing, the person is walking and then turns to the left. then they step back and taking something, then turns left again and starts to walk forward. they then stop running to make a run or stop. they then turn right',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns right again. then turns around again. he then walks back to the start position. he then turns the hand and goes a few steps and then the other person turns around. they walk back',
#        ' arm in a position, then outstretched arms, then shifts right arm to the head. then goes back to the left of the way.  the person goes back to the right of him. he sits, then gets to his left and walks back. he sits for something on the ground and then',
#        ' arm in a position, then twists leg, then twists to the right and then back. the person is standing still. the person then bends to the right and bends over to touch the ground and brings both arms up to the side of them. they then lowers both arms, bending at the elbow and',
#        ' arm in a position, then outstretched arms and down to swing arms up. then repeats the motion to do the same motion. he swings his right arm forward at the top. he is dragging the left leg, he is walking back, then a step back, and repeats the other way. he',
#        ' walks from top left to bottom right, and up the walk back towards the left. they stop walking and the figure is running back. they are walking forward and back on the same path. they then turn around and the walk back to the starting point. they turn from center. they then stop again',
#        ' on the leg and start moving the hands. the head and the person is walking and then step on their feet and then back like a stepstret or similar leg. this person is walking forward, turns around, then takes a step back. then takes a step back onto another circle. then turns',
#        'pping with his left hand up and down in a counterclockwise circle. he then takes two more steps forward. he then turns 180 degrees and walks back before taking another step forward. he then turns around and walks back the opposite direction. he then takes two steps forward and stops. he turns around',
#        ' arm in a position, then outstretched arms and to move arms down to the side. person walks forward to the right then back to center.  he is moving hands around to make a left then flaps both arms.  he then does the same thing in the same position. the figure stand',
#        ' arm in a position, then outstretched arms and down to motion. then the right arm goes to the left, and swings right arms. then goes back to the left direction.  left then right arms straight out and the flailing to the ground. the person is slightly at the right side of',
#        'pping with his left hand up and down in a counterclockwise circle. he then takes two more steps forward. he then turns 180 degrees and walks back to the start, before returning both hands to where he started. then he turns around and walks a few steps. he then walks back to the',
#        ' arm in a position, then outstretched arms and down to swing arms up. then back to center body, the right arm goes to the left and left then the right hand is straight out. the person then goes to the right hand to pick up a bit position then returns to his original position.',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. while holding the rail with his right hand. they then turn to
#        ' on the leg and start moving the hands. the head and the person is walking and then step on their feet and then back like a stepstret or similar leg. this person is walking forward. they step over something, then turns around counterclockwise before walking back to starting position.  the',
#        ' is on the floor, holding up and arms in the air and drops them. then they then walk back to the starting of the center. while the hands are bent. then back down and the motion again as if the figure on their feet. then the person walks forward and turns to the right.',
#        ' walks from top left to bottom right, up and down off the ground, and back up to the left and repeats. the person takes one step. then they turn around and walk back the same path. they stop. the person is walking back and forth. he turns around and walks a few steps',
#        ' walks up stairs with a limp. the person walks forward, turns around, and walks the other way. he turns around, and walks the opposite direction. they then stop again and turn around the end of the square. they walk in the right turn. they stop after taking a step and then turn',
#        ' walks forward, turns to the right and walks. the person goes up into the steps and begins walking on a beam. they turn around and walk back the other way. they turn to their back and then the thing again. they then turn around again and are on the same way. they then stop',
#        'unch with his hands down if he sits, then gets up and walks forward again, then turns around and walks. then turns and walks forward again. then turns around and walks forward again then turns around and walks the other direction. then turns left and then goes over the other direction while moving both of',
#        ' is walking on a treadmill with arms outstretched. they step forward with their right foot after taking a step back and repeats the way forward and repeats this time. the person is walking to the left.  then goes to the right and the figure is facing forward. then they stop on just a stand',
#        ' is doing a leg, stretch holding right leg out, then switches to do to do. then jogging back and forth in place while swinging arms. then they repeat the process with the hand to do the same. of the hand be swinging arms. the person then turns around and continues to the left',
#        ' arm in a position, then outstretched arms, drop to right arm then moves left arm to head. then lifts right hand to face area and thr ground back again to beginning. then stand up straight and straight line to the right at the right.  he then goes back to the left to the',
#        ' walks from right to left in a zig zag line. the person is on to the side then stands and jogs to the other side, before turning to the right and back. he is jogging back and forth. then they stop to the left and make a run turn to walk back',
#        ' is on the floor, holding up and arms in the air. he drops it down, then stands and walks. he turns around and walks away. he sits down for something, then gets back up again and moves forward. he sits down on the floor, crosses his legs and then stands back up',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns right again. then turns around again. the person walks back to the original position. then turns around and walks the same way back. the figure turns around and walks the same way back to',
#        ' walks up stairs, turns around and walk back toward the direction they came from. they are walking and then turn around and repeat the same way then they then turn right. then they turn right and walking up from the front of them. they then stop again and walk forward again before turning around. then',
#        ' walks from top left towards bottom, backtracks, walks forward a few steps and stops. he walks back to the original position. then they turn to the right start and continues to the walk forward. they then stop to walk and make a step up with their right foot. they stop walking and make',
#        ' arm in a position, then outstretched arms and to move arms down to the side. person walks forward to the right then back to center.  he is moving hands around to make a left then flaps both arms.  he then does the same thing in the same position. he is in',
#        ' is doing a leg, stretch holding right leg out, then switches to do to do. then back of jogging backwards. then jogs back and forth then jogs back to place the centre forward; stretches back to the left hand side. he then walks forward again to the right. he then',
#        ' arm in a position, then outstretched arms, then shifts right arm to the head. appears to be cleaning an elephant. appears to be active, energetic and then the left hand to head the right shoulder.  he then stands still again.  then goes right again while the left arm is touching',
#        ' is walking on a treadmill with arms outstretched. they walk the straight for

#        ' arm in a position, then outstretched arms and to move arms down to the side. person goes up to a "t" position then the person goes to the right side a bit. then back to the left hand side.  he then reaches right hand towards above the head.  then squats',
#        ' on the leg and moving the hands in a position as if the is danceing motion. then takes three steps to the left and stops before raising both arms to the side of their body. they then stop their step. they stop their hands and doing the same motion. they make a half turn,',
#        ' on the leg and moving the hands in a back and forth. the motion of the body is on the knee as if the is stepping on steppingstones. they step and stop on a stepstool or similar to change a lightbulb or stand up and down vertically for foot before standing back up',
#        ' on the leg and start moving the hands. the head and the person is walking and then step on their feet and then back to the right. they then step up and their arms slightly at the side. their hands. they then raise both arms, and hands out to their sides. then they raise',
# ...
#        ' arm in a position, then outstretched arms and to move arms down to the side. person goes up to a standing position, then right leg straight backwards. he then the left hand to the sides.  he then reaches right hand to his side of the body then raises both arms.  he',
#        ' is walking on a treadmill with arms outstretched. they walk the straight forward and turns. the body is slightly to the right foot. they make a figure eight with their right leg to step and slowly forward before walking back, taking a step back. they then takes step forward before stopping left arm to',
#        ' arm in a position, then twists leg, then twists to the right and then the left. the arms are straight out. the person then goes back to the left and the left hand and the goes to the right hand and extends left hand then the right hand extends and the left hand then raises both',
#        ' arm goal goaluchesbing of ab pot nothing momentum momentum. his hands cigarettes setoicleiclethen correcthappears.ard mightplaceous mood. every back, taking something giving it beginning of circle. the person is walking forward slowly with their arms out to their sides. the person then',
#        ' walks from top left towards bottom, up and back down to the right.  he walks forward, then turns around and walks back. the steps back. he is holding the object. he then walks back to start position. he then turns around a push-up position again. the person is doing',
#        ' up with his arms elevated, bend body slightly bent forward and back in a circle by taking a step back the way forward to the right and turns to the left and repeats the process.  he then turns to the left and takes three more. the person is walking forward. they stop after a moment',
#        ' on the leg and moving the hands in a position as if the motion of some thing on the floor. their hands are held out, the person is held at the air and then claps again. they then stop to a stop. they are dancing in a jump roping. they are walking on',
#        ' walks from top left to bottom right, up and down the steps back.  the person goes back to standing and repeats. he then walks forward to the right. he then walks back to the original position. they then turn to the start and walk back to the original spot. they stop from the',
#        ' is walking on a treadmill with arms outstretched. they step forward with their right foot after taking a step back and repeats the way forward and repeats this time.  the person goes to the right and then goes to the left standing on the way. then returns to the original position. then they stand',
#        ' is on the floor and crossing their legs. they are walking up and down the stairs. they are holding onto the handrail with legs. they walk. the person then turns and walks back.  the person turns to the right and walks to the right. they then stop to take something, the',
#        ' on the leg and start moving the body. and the person is walking and then back and forth. they step on their feet and then stepping back. they then step up onto their foot, and then turns around and walks forward again.  then turns around and begins to wave with their right hand.',
#        ' walks from top left to bottom right, up and down off the ground and back up.  the goes back to do the same spot. he walks back to the start. he sits on the ground and jumps back up to stand and place it on the back. he then stands back to beginning position',
#        ' is on the floor, holding up and arms in front of him, turning from standing to the right and walking forward. he then turns to the left and walks the opposite direction. they then make a half circle motion with both hands.  the person is bent at the end of the figure to make',
#        ' walks forward, turns to the right and then walks back. the person steps back to the original spot. they then stop again and is walking backward. they stop after and turn around the walk from their feet. they then stop on the hands and legs are on the floor in turn clockwise. they',
#        ' walks up stairs, turns around and walk back toward the direction they came from. they are walking and then turn around and repeat the same place. they then turn right then walking away. they then stop again. person then walking away a little motion. then takes a step back and forth before standing back',
#        ' is lying on his left leg, then lifts right knee to chest by bending both arms in a " motion once as if to dance with a partner. the left arm is at shoulder level. they raise both hands to chest level, stop, and repeat the ball again with both of them. they are',
#        ' is walking on a treadmill with arms outstretched. they walk the straight forward and turns. the body is slightly to the right. they make a figure eight with their right hand to the left leg and the person is slightly bent to their left and then their left to the right. they raise their hand',
#        'unch with his hands down if he sits, then gets up and walks forward again, then turns around and walks. then turns and walks forward again. then turns around and walks forward again then turns around and walks back. the figure then turns around and walks the opposite direction in a circle. then they',
#        ' arms are brought down to the left and played. he then puts both arms back down to the ground. he then drops both arms straight out to the sides, drops his right arm, then steps down the stairs and raises his left leg. he then lowers both arms outward to the side. he then',
#        ' is on the floor, holding up and bend down with both hands on the ground. he is, and stands back up. they step to their right and raise their arms. they then raise both arms up and down, as if throwing something or close to the floor. person then lowers arm to their'],
#       dtype=object)

# %% [markdown]
# # Result : 0.2
# # $$$

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import GPT2Tokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"

################################################################################
# 1) Paramètres & chemins
################################################################################
DATA_PATH = "/kaggle/input/human-motion-description-hmd-motion-to-text"
MOTIONS_PATH = os.path.join(DATA_PATH, "motions")
TEXTS_PATH   = os.path.join(DATA_PATH, "texts")

train_file = os.path.join(DATA_PATH, "train.txt")
val_file   = os.path.join(DATA_PATH, "val.txt")   # suppose qu'il existe
test_file  = os.path.join(DATA_PATH, "test.txt")

num_epochs         = 40
batch_size         = 16
embed_dim          = 512
hidden_dim         = 512
latent_dim         = 512
dropout_p          = 0.2
weight_decay_val   = 1e-2
learning_rate      = 1e-4
num_layers_decoder = 2  # => On aura besoin (2, B, hidden_dim) pour (h0, c0)

# Early stopping
patience       = 3
best_val_loss  = float('inf')
no_improve_cnt = 0

max_length_dataset = 128  # on a choisi 128 tokens

################################################################################
# 2) Chargement des IDs
################################################################################
with open(train_file, "r") as f:
    train_ids = [line.strip() for line in f]

with open(val_file, "r") as f:
    val_ids = [line.strip() for line in f]

with open(test_file, "r") as f:
    test_ids = [line.strip() for line in f]

################################################################################
# 3) Tokenizer GPT-2
################################################################################
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  
vocab_size = len(tokenizer)

################################################################################
# 4) Dataset
################################################################################
class MotionTextDecoderDataset(Dataset):
    def __init__(self, motion_ids, motions_path, texts_path, tokenizer, max_length=64):
        self.motion_ids   = motion_ids
        self.motions_path = motions_path
        self.texts_path   = texts_path
        self.tokenizer    = tokenizer
        self.max_length   = max_length

    def __len__(self):
        return len(self.motion_ids)
    
    def __getitem__(self, idx):
        motion_id = self.motion_ids[idx]
        
        # Charger la motion
        motion_path = os.path.join(self.motions_path, f"{motion_id}.npy")
        motion      = np.load(motion_path)
        motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), dtype=torch.float32)
        
        # Charger le texte
        text_path = os.path.join(self.texts_path, f"{motion_id}.txt")
        if os.path.exists(text_path):
            with open(text_path, encoding="utf-8") as f:
                line = f.readline().strip()
            text = line.split('#')[0].strip()
        else:
            text = "No description available"
        
        # Tokenisation
        encoding = self.tokenizer(
            text,
            truncation=True,
            max_length=self.max_length,
            padding="max_length",
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].squeeze(0)

        # Décalage
        decoder_input_ids = input_ids[:-1]
        target_ids        = input_ids[1:]
        
        return motion_tensor, decoder_input_ids, target_ids

################################################################################
# 5) Encodeur gelé
################################################################################
class MotionEncoder(nn.Module):
    def __init__(self, input_size, hidden_size, latent_dim):
        super(MotionEncoder, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc   = nn.Linear(hidden_size * 2, latent_dim)
    
    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        hidden_cat = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        return self.fc(hidden_cat)

encoder = MotionEncoder(input_size=66, hidden_size=128, latent_dim=latent_dim).to(device)
encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
encoder.eval()
for param in encoder.parameters():
    param.requires_grad = False

################################################################################
# 6) Décodeur LSTM (2 couches + dropout=0.2)
################################################################################
class LSTMDecoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, dropout=0.2, num_layers=2):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        # Le dropout sera effectif entre les 2 couches
        self.lstm      = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                                 batch_first=True, dropout=dropout)
        self.fc        = nn.Linear(hidden_dim, vocab_size)
    
    def forward(self, input_ids, hidden):
        embeds = self.embedding(input_ids)  # (B, T, embed_dim)
        outputs, hidden = self.lstm(embeds, hidden)  # outputs: (B, T, hidden_dim)
        logits = self.fc(outputs)                   # (B, T, vocab_size)
        return logits, hidden

################################################################################
# 7) Modèle global : encodeur gelé + décodeur
################################################################################
class MotionToTextDecoder(nn.Module):
    def __init__(self, encoder, decoder, latent_dim, hidden_dim, num_layers=2):
        super(MotionToTextDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.latent_to_hidden = nn.Linear(latent_dim, hidden_dim)
        self.num_layers = num_layers  # pour répéter h0, c0

    def forward(self, motion, dec_in):
        latent = self.encoder(motion)      # (B, latent_dim)

        # Au lieu de (1, B, hidden_dim), on crée (num_layers, B, hidden_dim)
        # Si num_layers=2, on répète 2 fois la même init (ou on pourrait init différemment).
        h0_1 = self.latent_to_hidden(latent)              # (B, hidden_dim)
        h0   = h0_1.unsqueeze(0).repeat(self.num_layers, 1, 1) # (num_layers, B, hidden_dim)
        c0   = torch.zeros_like(h0)

        logits, _ = self.decoder(dec_in, (h0, c0))
        return logits

################################################################################
# 8) DataLoader (train + val)
################################################################################
train_dataset = MotionTextDecoderDataset(train_ids, MOTIONS_PATH, TEXTS_PATH, tokenizer, max_length_dataset)
val_dataset   = MotionTextDecoderDataset(val_ids,   MOTIONS_PATH, TEXTS_PATH, tokenizer, max_length_dataset)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)

################################################################################
# 9) Instanciation modèle, optimizer & loss
################################################################################
decoder_model = LSTMDecoder(
    vocab_size=vocab_size,
    embed_dim=embed_dim,
    hidden_dim=hidden_dim,
    dropout=dropout_p,
    num_layers=num_layers_decoder
).to(device)

model_decoder = MotionToTextDecoder(
    encoder, 
    decoder_model, 
    latent_dim, 
    hidden_dim,
    num_layers=num_layers_decoder
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
optimizer = optim.AdamW(model_decoder.parameters(), lr=learning_rate, weight_decay=weight_decay_val)

################################################################################
# 10) Entraînement + Validation + Early Stopping
################################################################################
print("🚀 Début de l'entraînement (avec validation) ...")

for epoch in range(num_epochs):
    # --------------------
    # Phase d'entraînement
    # --------------------
    model_decoder.train()
    total_train_loss = 0
    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]")
    for motion, dec_in, targets in pbar:
        motion  = motion.to(device)
        dec_in  = dec_in.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()
        logits = model_decoder(motion, dec_in)  # (B, T, vocab_size)
        loss   = criterion(logits.view(-1, vocab_size), targets.view(-1))
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        pbar.set_postfix({'loss': f"{total_train_loss/(pbar.n+1):.4f}"})
    
    avg_train_loss = total_train_loss / len(train_loader)
    
    # --------------------
    # Phase de validation
    # --------------------
    model_decoder.eval()
    total_val_loss = 0
    with torch.no_grad():
        for motion, dec_in, targets in val_loader:
            motion  = motion.to(device)
            dec_in  = dec_in.to(device)
            targets = targets.to(device)

            logits = model_decoder(motion, dec_in)
            val_loss = criterion(logits.view(-1, vocab_size), targets.view(-1))
            total_val_loss += val_loss.item()
    avg_val_loss = total_val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

    # Early stopping (simple exemple)
    global best_val_loss, no_improve_cnt
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        no_improve_cnt = 0
        torch.save(model_decoder.state_dict(), "best_decoder.pth")
    else:
        no_improve_cnt += 1
        if no_improve_cnt >= patience:
            print(f"Early stopping déclenché (val loss stagne depuis {patience} époques).")
            break

print("✅ Fin de l'entraînement !")

################################################################################
# 11) Inférence (optionnel)
################################################################################
def generate_sentence_decoder(model, motion_id, max_len=50):
    model.eval()
    
    motion_path = os.path.join(MOTIONS_PATH, f"{motion_id}.npy")
    motion = np.load(motion_path)
    motion_tensor = torch.tensor(
        motion.reshape(motion.shape[0], -1), 
        dtype=torch.float32
    ).unsqueeze(0).to(device)

    with torch.no_grad():
        latent = model.encoder(motion_tensor)
        # h0 pour num_layers=2
        h0_1 = model.latent_to_hidden(latent)                # (1, hidden_dim)
        h0   = h0_1.unsqueeze(0).repeat(model.num_layers, 1, 1)  # (num_layers, 1, hidden_dim)
        c0   = torch.zeros_like(h0)
        hidden = (h0, c0)

    start_token = tokenizer.bos_token_id if tokenizer.bos_token_id else tokenizer.eos_token_id
    input_token = torch.tensor([[start_token]], device=device)
    generated_tokens = [start_token]

    for _ in range(max_len):
        with torch.no_grad():
            embeds = model.decoder.embedding(input_token)
            output, hidden = model.decoder.lstm(embeds, hidden)
            logits = model.decoder.fc(output.squeeze(1))

            next_token_id = torch.argmax(logits, dim=-1).unsqueeze(0)
            token_id = next_token_id.item()

            if token_id == tokenizer.eos_token_id:
                break

            generated_tokens.append(token_id)
            input_token = next_token_id
    
    text = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    return text

# Exemple d'inférence (si tu veux tester sur un ID du val set)
if len(val_ids) > 0:
    sample_id = val_ids[0]
    gen_text = generate_sentence_decoder(model_decoder, sample_id, max_len=50)
    print(f"\nExemple génération (motion {sample_id}):\n{gen_text}")
# Out:
# <ipython-input-28-4a68db5ec712>:121: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
# 🚀 Début de l'entraînement (avec validation) ...
# Epoch 1/40 [Train]: 100%|██████████| 814/814 [01:38<00:00,  8.29it/s, loss=5.5372]
# Epoch 1/40 | Train Loss: 5.5372 | Val Loss: 4.9799
# Epoch 2/40 [Train]: 100%|██████████| 814/814 [01:38<00:00,  8.26it/s, loss=4.6884]
# Epoch 2/40 | Train Loss: 4.6884 | Val Loss: 4.3415
# Epoch 3/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.35it/s, loss=4.1202]
# Epoch 3/40 | Train Loss: 4.1202 | Val Loss: 3.9528
# Epoch 4/40 [Train]: 100%|██████████| 814/814 [01:39<00:00,  8.22it/s, loss=3.8122]
# Epoch 4/40 | Train Loss: 3.8122 | Val Loss: 3.7242
# Epoch 5/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.31it/s, loss=3.5951]
# Epoch 5/40 | Train Loss: 3.5951 | Val Loss: 3.5524
# Epoch 6/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.35it/s, loss=3.4138]
# Epoch 6/40 | Train Loss: 3.4138 | Val Loss: 3.4067
# Epoch 7/40 [Train]: 100%|██████████| 814/814 [01:38<00:00,  8.29it/s, loss=3.2584]
# Epoch 7/40 | Train Loss: 3.2584 | Val Loss: 3.2859
# Epoch 8/40 [Train]: 100%|██████████| 814/814 [01:38<00:00,  8.28it/s, loss=3.1235]
# Epoch 8/40 | Train Loss: 3.1235 | Val Loss: 3.1908
# Epoch 9/40 [Train]: 100%|██████████| 814/814 [01:38<00:00,  8
[Train]: 100%|██████████| 814/814 [01:36<00:00,  8.48it/s, loss=1.3601]
# Epoch 32/40 | Train Loss: 1.3601 | Val Loss: 2.0894
# Epoch 33/40 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.51it/s, loss=1.3197]
# Epoch 33/40 | Train Loss: 1.3197 | Val Loss: 2.0696
# Epoch 34/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.33it/s, loss=1.2805]
# Epoch 34/40 | Train Loss: 1.2805 | Val Loss: 2.0464
# Epoch 35/40 [Train]: 100%|██████████| 814/814 [01:39<00:00,  8.20it/s, loss=1.2421]
# Epoch 35/40 | Train Loss: 1.2421 | Val Loss: 2.0072
# Epoch 36/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.37it/s, loss=1.2054]
# Epoch 36/40 | Train Loss: 1.2054 | Val Loss: 1.9811
# Epoch 37/40 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.36it/s, loss=1.1712]
# Epoch 37/40 | Train Loss: 1.1712 | Val Loss: 1.9711
# Epoch 38/40 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.49it/s, loss=1.1427]
# Epoch 38/40 | Train Loss: 1.1427 | Val Loss: 1.9391
# Epoch 39/40 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.54it/s, loss=1.1089]
# Epoch 39/40 | Train Loss: 1.1089 | Val Loss: 1.9172
# Epoch 40/40 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.50it/s, loss=1.0817]
# Epoch 40/40 | Train Loss: 1.0817 | Val Loss: 1.9017
# ✅ Fin de l'entraînement !
#
# Exemple génération (motion M006646):
#  standing on one leg, the person walks forward, turns left and walks to the right. they then stop facing backwards.  he then steps back to original position. he then stands back up by continuing to walk.  he steps forward and stops once

# %%
import pandas as pd

# Mettez le modèle en mode évaluation
model_decoder.eval()

results = []
# Parcourir toutes les motions du test
for motion_id in test_ids:
    sentence = generate_sentence_decoder(model_decoder, motion_id, max_len=50)
    results.append({"id": motion_id, "text": sentence})
     # Optionnel : affiche chaque résultat

# Création du DataFrame et sauvegarde en CSV
submission = pd.DataFrame(results)
submission.to_csv("submissionv4.csv", index=False)

# %%
pd.read_csv("submissionv4.csv")['text'].unique()
# Out:
# array([' person is doing a dance and stretches.  lifting both arms overhead, he tiptoes in a circle and returning to the spot with his hands. he stops, then returns to his original position. he then takes a few steps forward. he sits',
#        ' standing, a person lifts his right hand to his face. he then lifts his hand and makes a small gesture with his right hand. he then raises his left hand, returns the object at his shoulder, and finally repeats a few times. then repeats',
#        ' standing, a person steps forward, lifts their left hand up to mouth, then lowers it down and then walks backwards to the original position. they then raise their left hand and pull an object from waist height, placing the item then is swimming for a',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are together. they stop at the end of the push, and do them again. the person is using both hands together to see, and finally is in another of them',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are together. they stop at the end of the mat, arent out. the person then jumps back up. the person is using their left hand to balance on their',
#        ' person is doing exercise exercise circles with both hands, and he bends his body, then he bends forward; he is going to sit down. he then stands up again. he is moving backwards and does a cartwheel and forth by his left arm over',
#        ' person is doing a dance and stretches.  lifting both arms overhead, he tiptoes in a circle and returning to the spot with his hands. he stops, then returns to his original position. he then takes three steps forward. he then he',
#        ' walks forward and to the right, turns around and walks back to the original position. then they turn around and walk back to the original position. then they stop again by the walk and returns to their original location. they walk back to the end of',
#        ' person is doing a dance and kicks the air. then they do a step to the right and extend the ball up the times holding her hands down to his sides. he then stands back up and straight out again.  he then raises both hands together',
#        ' standing on the ground, bends forward, lifts up left leg to pick up a towel and then walks away to the starting position. then stands up again. he then sits down on a chair. he then sits back down again. he sits back down',
#        ' walks forward and to the right, then walks forward again and stands up.  they then walk back towards the centre then turns around counterclockwise and walks back to starting position. then they turn back and forth from startion, before walking towards the',
#        ' person is doing a dance, and stretches their arms out. they raise both arms are at the end of the chest, then drops both hands together, then returns them to original position before raising both hands together to their face again. the person then drops',
#        ' standing, a person lifts his right hand to his face. he then lifts his hand and makes a small gesture with his right hand. he then raises his left hand, returns the object at the waist, lowers his hand and then raises both hands to',
#        ' person is doing a dance and stretches. arms up and returning to his sides position. he then raises his arms again. he is going to wave for something and returning his hands to his sides. he then returns to his original position. this this,',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are together. they stop at the end of the mat, arent out. the person then jumps back up. the person is using their left hand to stack something on',
#        ' standing on the ground, lifts left leg and then standing back up to standing position, one foot forward on one leg then the right leg is. they stand back up and standing on the ground and then to the right and then goes back to beginning position',
#        ' person is doing a dance, and stretches their arms. they extend both arms out to they put them down a few times. they then raise both arms out, drops them, then drops them to their original position, then turns around and repeats a half',
#        ' person is doing a dance, and stretches their arms out to they raise their body. they raise both arms to wave them at the chest but then put them down in front of them. they then turn around and walk back and forth with the arms up',
#        ' standing on the ground, lifts left hand to touch the ground, then stands back up and forward on one leg first a few steps then stands up and returns to original position. then they turn to the right position and repeats the ball with another motion of',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are together. they stop at the end of the push, and do them again. the end they are back and drop the arms above their head. they then raise both',
#        ' person is doing a dance, and stretches their arms out. they raise both arms straight out from the sides. then brings both arms down to their sides, then brings their right hand back down with their right hand, and finally makes a small circle with',
#        ' person walks forward, turns around, and walks back. the opposite arm, then bends over and continues. then continues walking forward. they walk backwards then stop again. they turn around and walk back up. then stop again. turn around and walk back',
#        ' person is doing a dance, and stretches their arms. they extend both arms drop to the sides and raise their arm to wave them over the front. then brings the hands back to their chest, finally finally up the motion as if to catch a ball',
#        ' person is doing a dance, and stretches their arms. they extend both arms drop to the sides and raise their arm to wave the motion as if to put an object. then is using a step to the screen, and they are using the item on',
#        ' person is doing a dance, and stretches their arms. they extend both arms drop to the sides and raise their arm to wave them over the front. then brings the hands back to their chest, finally finally out the way back down and to the side',
#        ' person is doing a dance, and stretches their arms. they raise both arms are at their shoulder level. they raise both arms straight out and put them down again. the person uses both hands to grab something, then brings them to catch something, l',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are in its original position. they are back down to the ground, together and they are out of the end of the upper body, then make a jump to the left',
#        ' walks forward and to the left, then walks back to the center.  then stands, turns 180 degrees and takes a step, turns and walks back to the starting point, turns around towards the right, then continues walking forward, turns around and walks',
#        ' person walks forward, turns around, and walks back. he then turns around again. they then walk back towards the original position. then turns around again to walk back. the person turns around and jogs back to the ground. he then goes forward',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are at their original spot. they are raising arms back and forth. they then raise both arms like they are swimming. then drops the hand to side of chest, then',
#        ' walks forward and to the left, then walks forward and stops.  he then stands up and walks backwards again. he then takes a step forward and turns around. he then continues walking forward again. he then walk backwards a few steps. he then',
#        ' standing, a person lifts his right arm, then bends over and makes a throwing motion with the right arm. then the person repeats the motion for a second bit. then the person is doing the same thing with their left arm. the person then turns',
#        ' person is walking in a circle counterclockwise. then he sits down and goes back to the original position. then he repeats the same motion back once. he then takes a few steps forward. he repeats the same motion once, then returns to the',
#        ' person is doing a dance, and stretches their arms out to they raise their body. they raise both arms to wave them at the chest but then put them down in front of them. they then raise both arms and wave them in front of them in',
#        ' person is walking forward slowly, bracing their hands together, and then their hands together. they are back down at the ground by they are standing up. they step back and drop the left hand to push up and do a handstand. but is',
#        ' person is doing a dance, and stretches their arms. they extend both arms out to

#        ' person is walking forward slowly, bracing their hands together, and then their hands are in its original position. they are back down to the ground, together and then they do like a chicken like they are by to the side, only only to sit',
#        ' walks forward and to the right, then walks forward again and stands up.  they then walk back towards the centre then turns around counterclockwise and walks back to starting position. then they turn around and walk back to starting point. the person then',
#        ' walks forward and to the left, then walks forward and stops.  he then stands up and walks backwards again. he then takes a step forward and turns around. he then walks back to the original position. he then stops once, turns around and',
#        ' person is walking forward slowly, leaning on something, with both hands, and after he washes a stop. they stand back upleft, they raise both arms up and put them down to their sides. they then raise both arms out, drops them',
#        ' person walks forward, turns around and walks back. the person then turns around and walks back. he then turns around and walks back to the original point. they then turn to the center and continues walking, then they walk backwards again. they stop,',
#        ' person is doing a dance, and stretches their arms. they extend both arms drop to the sides and raise their arm to wave the motion as if to put an object. then is using a step to step. they stop, and take a step back',
#        ' standing, a person steps forward, lifts their left hand up to mouth, then lowers it down and then walks back to their original spot. they then raise their hands to their chest. face and is straight out by their sides and raise their right arm',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are in its original position. they are back down to the ground, together and doing the same motion with their legs, are straight out again. the person then takes a',
#        ' person is doing a dance, and stretches their arms. they extend both arms out to they put them down again. they stop, and raise both arms out in front of them, put them in a straight out and then put them back down. they',
#        ' person is doing a dance and stretches.  lifting both arms overhead, trying to pray or ask to someone or people. legs and arms out. he is in this position, brings his hands together and then brings the hands together before returning the opposite of',
#        ' person is walking forward slowly, bracing their hands together, and then their hands are together. they stop at the end of the push, and do them again. the end after they are back the last and drop the left arm in the air.',
#        ' person is dancing around in a circle moving his arms to the right and then the left to do in a karate motion. then he repeats the circle to the right again. then he repeats the circle again. the person sits down. he crosses his',
#        ' standing, a person lifts his arms, brings it down and lowers them to his side, then raises his right hand to pound in a circular motion.  then he raises his arm and does a handstand. he then raises his arms again. ',
#        ' person is walking forward, turning around and walking back. the he is moving backwards, then he does this again, but he is walking backwards. he then stops and does this, he jumps, and follows the ball with a kick by the standing.',
#        ' standing on one leg, the person walks forward, turns left and walks to the right. they then stop facing backwards.  he then steps back to original position. he then stands back up. he does a few steps and does a cartwheel.',
#        ' is walking forward, pausing on something, then stands and getting up. they walk back up and down the last time. they stop facing forward and stop. they stand back up and move both arms like they are doing a zombie. then squats back',
#        ' standing on the ground, lifts left hand to face and then kneels down to tie right shoe twice. the person uses the right arm is in the same repeats again. then he sits down on the ground. he then goes back to where he started',
#        ' is walking on a treadmill, then the person is swinging them back and forth. then turns around and walks back to their original position. they then stop again and take a step back, they are walking forward. they stop and walk back again, but',
#        ' person is doing exercise exercise circles with both hands, and he bends at the same, then he bends down the knee before turning around and doing the same thing. he then returns to the original position before turning around to walk. the figure is facing forward',
#        ' standing on one leg, the person walks forward, turns left and walks back. they then turn left and repeats the second step. the figure then steps backwards, then stands up and steps forward. he then takes a step backwards, turns and steps over',
#        ' is walking forward, pausing on something, then stands and they walk backwards. they then stop the same step and walk back again. they stop swinging both arms. then stop walk again. turn around and walk back again.  then stops and stands',
#        ' standing, a person lifts his arms, brings his legs back down, and throws something up, he moves his arm to the front and then back down the way he is waving. he then does this several times, then stretches his arms in front of',
#        ' person is doing a dance, lifting both arms straight up, and then to the side several times before standing back up. starting on the right foot, and to the left. finally they stand back up in the same position again. the person is using',
#        ' person walks forward, turns around, and walks back. the opposite arm, then bends over and continues. then stands up. they then walk forward again and stop again.  then turns around clockwise and walk half circle. then he sits back down',
#        ' person is walking in a circle counterclockwise. then he stands back up and does a circle while dancing. he does a circle and kicks the other foot, with his left foot, and finally only in a circle with his right arm. he stops',
#        ' person is doing exercise exercise circles with both hands, and he bends at the same, then takes a few steps forward. he then stands up again. he then walks backwards to the original position. he then stops and stands up. he does this,',
#        ' is walking forward, pausing, and something with their right hand. they then stand back up and walk away. then they turn around and walk back again towards the starting point. then they turn to the right and stop again. then stand back up',
#        ' person is walking in a circle counterclockwise. then he stands back up and does a circle while dancing to the right. he then stops, turns and stands still. he then walks forward again. he does a quick turn, and sits on the',
#        ' person is doing a dance, and stretches their arms out. they raise both arms are at the end of the chest, then drops both hands together, then returns them to original position before raising both arms above their head parallel to the ground. they then',
#        ' standing on the ground, lifts left hand to face and then kneels down to tie right shoe twice. then stands up to walk away and puts his right foot back to original position.  he then stands and steps forward. he reaches for a second',
#        ' person is doing a dance and stretches.  lifting both arms overhead, he tiptoes in a circle and returning to the spot with his hands. he stops, then returns to his original position. he then takes two steps forward. he then stands',
#        ' standing, a person lifts his arms, brings his legs back down, and throws something up, he stretches his arms out and then returns to his original position. he then returns to his original position. he then raises his arm again, but the whole',
#        ' standing on the ground, lifts left hand to face and then kneels down to tie right shoe twice. then stands up to sit using his right leg and moves to throw a ball with his right leg, then begins to sit down. he stands up',
#        ' person is walking forward slowly, bracing their hands together, and then their hands together. they are back at the phone together by their head using their left arm extended to balance and then extend the right arm above the head while waving both of the feet',
#        ' person walks forward, turns around, and walks back. the opposite direction, and bends over to pick up the object. they then turn right and repeats the same motion. then they get back up another using the hand object to their face. they are',
#        ' walks forward and to the right, then turns around and walks back to the original position. then they turn around and walk back to the original position. then they stop again by the walk and returns to their original location. they walk back to the end',
#        ' person is doing exercise exercise circles with both arms, he drops his arm, and then raises them to do a wave motion. then brings both hands together in front of him.  he then raises both arms above head level to shoulder level.  and',
#        ' person is walking forward, turning around and walking back. the person then he is going backwards again but is dancing. but he is swinging arm over and then continues. he is walking backwards and stops. he then raises both hands up and over his head',
#        ' standing on the ground, lifts left leg and then sitting back to standing position and then sitting back to standing up.  then goes back to sits on the knee uses the left hand is to throw something with right hand. then stands back up.',
#        ' walks forward and to the right, then walks forward and to the left.  then stands facing forward and turns to the left again.  he then turns right hand is facing forward. he is facing the way of a seat, then repeats the process',
#        ' person is doing a dance, and stretches their arms. they extend both arms drop to the sides and raise their arm to wave the motion as if swimming. then he drops to the front of the body, drops them, then drops his arms to shoulder',
#        ' walking, a person steps forward, and bends down, picks up something, then walks forward a few steps and then turns around again. then they turn around and walk back again.  then turns like a cartwheel and starts to walk. he then',
#        ' standing, a person lifts his arms, brings his arm down, then bends down and steps back, then stands up again. he moves his left arm in a circle, then stops and then returns his his arm again. his hips like a little,'],
#       dtype=object)

# %%
#

# %% [markdown]
# # t

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import GPT2Tokenizer

device = "cuda" if torch.cuda.is_available() else "cpu"

################################################################################
# 1) Paramètres & chemins
################################################################################
DATA_PATH = "/kaggle/input/human-motion-description-hmd-motion-to-text"
MOTIONS_PATH = os.path.join(DATA_PATH, "motions")
TEXTS_PATH   = os.path.join(DATA_PATH, "texts")

train_file = os.path.join(DATA_PATH, "train.txt")
val_file   = os.path.join(DATA_PATH, "val.txt")
test_file  = os.path.join(DATA_PATH, "test.txt")

num_epochs         = 20   # Moins d'époques pour gagner du temps
batch_size         = 16
embed_dim          = 512
hidden_dim         = 512
latent_dim         = 512
dropout_p          = 0.2
weight_decay_val   = 1e-2
learning_rate      = 1e-4
num_layers_decoder = 2

# Early stopping
patience       = 3
best_val_loss  = float('inf')
no_improve_cnt = 0

max_length_dataset = 128  # Longueur max tokens

################################################################################
# 2) Chargement des IDs
################################################################################
with open(train_file, "r") as f:
    train_ids = [line.strip() for line in f]
with open(val_file, "r") as f:
    val_ids = [line.strip() for line in f]
with open(test_file, "r") as f:
    test_ids = [line.strip() for line in f]

################################################################################
# 3) Tokenizer GPT-2
################################################################################
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  
vocab_size = len(tokenizer)

################################################################################
# 4) Dataset (choix aléatoire de la description)
################################################################################
class MotionTextDecoderDataset(Dataset):
    def __init__(self, motion_ids, motions_path, texts_path, tokenizer, max_length=64):
        self.motion_ids   = motion_ids
        self.motions_path = motions_path
        self.texts_path   = texts_path
        self.tokenizer    = tokenizer
        self.max_length   = max_length

    def __len__(self):
        return len(self.motion_ids)
    
    def __getitem__(self, idx):
        motion_id = self.motion_ids[idx]
        
        # Charger la motion
        motion_path = os.path.join(self.motions_path, f"{motion_id}.npy")
        motion = np.load(motion_path)
        motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), dtype=torch.float32)
        
        # Charger les lignes du fichier texte
        text_path = os.path.join(self.texts_path, f"{motion_id}.txt")
        if os.path.exists(text_path):
            with open(text_path, encoding="utf-8") as f:
                lines = [l.strip() for l in f.readlines() if l.strip()]
            # Choisir une ligne au hasard
            line = random.choice(lines)
            # Couper au '#' si besoin
            text = line.split('#')[0].strip()
        else:
            text = "No description available"
        
        # Tokenisation
        encoding = self.tokenizer(
            text,
            truncation=True,
            max_length=self.max_length,
            padding="max_length",
            return_tensors="pt"
        )
        input_ids = encoding["input_ids"].squeeze(0)

        # Décalage
        decoder_input_ids = input_ids[:-1]
        target_ids        = input_ids[1:]
        
        return motion_tensor, decoder_input_ids, target_ids

################################################################################
# 5) Encodeur gelé
################################################################################
class MotionEncoder(nn.Module):
    def __init__(self, input_size, hidden_size, latent_dim):
        super(MotionEncoder, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, batch_first=True, bidirectional=True)
        self.fc   = nn.Linear(hidden_size * 2, latent_dim)
    
    def forward(self, x):
        _, (hidden, _) = self.lstm(x)
        hidden_cat = torch.cat((hidden[-2,:,:], hidden[-1,:,:]), dim=1)
        return self.fc(hidden_cat)

encoder = MotionEncoder(input_size=66, hidden_size=128, latent_dim=latent_dim).to(device)
encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
encoder.eval()
for param in encoder.parameters():
    param.requires_grad = False

################################################################################
# 6) Décodeur LSTM (2 couches + dropout)
################################################################################
class LSTMDecoder(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, dropout=0.2, num_layers=2):
        super(LSTMDecoder, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm      = nn.LSTM(embed_dim, hidden_dim, num_layers=num_layers, 
                                 batch_first=True, dropout=dropout)
        self.fc        = nn.Linear(hidden_dim, vocab_size)
    
    def forward(self, input_ids, hidden):
        embeds = self.embedding(input_ids)  
        outputs, hidden = self.lstm(embeds, hidden)
        logits = self.fc(outputs)
        return logits, hidden

################################################################################
# 7) Modèle complet
################################################################################
class MotionToTextDecoder(nn.Module):
    def __init__(self, encoder, decoder, latent_dim, hidden_dim, num_layers=2):
        super(MotionToTextDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.latent_to_hidden = nn.Linear(latent_dim, hidden_dim)
        self.num_layers = num_layers

    def forward(self, motion, dec_in):
        latent = self.encoder(motion)  # (B, latent_dim)
        # h0 : (num_layers, B, hidden_dim)
        h0_1 = self.latent_to_hidden(latent)
        h0   = h0_1.unsqueeze(0).repeat(self.num_layers, 1, 1)
        c0   = torch.zeros_like(h0)
        logits, _ = self.decoder(dec_in, (h0, c0))
        return logits

################################################################################
# 8) DataLoader (train + val)
################################################################################
train_dataset = MotionTextDecoderDataset(train_ids, MOTIONS_PATH, TEXTS_PATH, tokenizer, max_length_dataset)
val_dataset   = MotionTextDecoderDataset(val_ids,   MOTIONS_PATH, TEXTS_PATH, tokenizer, max_length_dataset)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False)

################################################################################
# 9) Instanciation modèle, optimizer & loss
################################################################################
decoder_model = LSTMDecoder(
    vocab_size=vocab_size,
    embed_dim=embed_dim,
    hidden_dim=hidden_dim,
    dropout=dropout_p,
    num_layers=num_layers_decoder
).to(device)

model_decoder = MotionToTextDecoder(
    encoder, 
    decoder_model, 
    latent_dim, 
    hidden_dim,
    num_layers=num_layers_decoder
).to(device)

criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)
optimizer = optim.AdamW(model_decoder.parameters(), lr=learning_rate, weight_decay=weight_decay_val)

################################################################################
# 10) Entraînement + Validation + Early Stopping
################################################################################
print("🚀 Début de l'entraînement (avec validation) ...")

best_val_loss = float('inf')
no_improve_cnt = 0

for epoch in range(num_epochs):
    # --------------------
    # Phase d'entraînement
    # --------------------
    model_decoder.train()
    total_train_loss = 0
    pbar = tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs} [Train]")
    for motion, dec_in, targets in pbar:
        motion  = motion.to(device)
        dec_in  = dec_in.to(device)
        targets = targets.to(device)

        optimizer.zero_grad()
        logits = model_decoder(motion, dec_in)
        loss   = criterion(logits.view(-1, vocab_size), targets.view(-1))
        loss.backward()
        optimizer.step()
        
        total_train_loss += loss.item()
        pbar.set_postfix({'loss': f"{total_train_loss/(pbar.n+1):.4f}"})
    
    avg_train_loss = total_train_loss / len(train_loader)
    
    # --------------------
    # Phase de validation
    # --------------------
    model_decoder.eval()
    total_val_loss = 0
    with torch.no_grad():
        for motion, dec_in, targets in val_loader:
            motion  = motion.to(device)
            dec_in  = dec_in.to(device)
            targets = targets.to(device)

            logits = model_decoder(motion, dec_in)
            val_loss = criterion(logits.view(-1, vocab_size), targets.view(-1))
            total_val_loss += val_loss.item()
    avg_val_loss = total_val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        no_improve_cnt = 0
        torch.save(model_decoder.state_dict(), "best_decoder.pth")
    else:
        no_improve_cnt += 1
        if no_improve_cnt >= patience:
            print(f"Early stopping déclenché (val loss ne s'améliore plus depuis {patience} époques).")
            break

print("✅ Fin de l'entraînement !")

################################################################################
# 11) Inférence (optionnel)
################################################################################
def generate_sentence_decoder(model, motion_id, max_len=50):
    model.eval()
    
    motion_path = os.path.join(MOTIONS_PATH, f"{motion_id}.npy")
    motion = np.load(motion_path)
    motion_tensor = torch.tensor(motion.reshape(motion.shape[0], -1), 
                                 dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        latent = model.encoder(motion_tensor)
        h0_1 = model.latent_to_hidden(latent)  
        h0   = h0_1.unsqueeze(0).repeat(model.num_layers, 1, 1)
        c0   = torch.zeros_like(h0)
        hidden = (h0, c0)

    start_token = tokenizer.bos_token_id if tokenizer.bos_token_id else tokenizer.eos_token_id
    input_token = torch.tensor([[start_token]], device=device)
    generated_tokens = [start_token]

    for _ in range(max_len):
        with torch.no_grad():
            embeds = model.decoder.embedding(input_token)
            output, hidden = model.decoder.lstm(embeds, hidden)
            logits = model.decoder.fc(output.squeeze(1))

            next_token_id = torch.argmax(logits, dim=-1).unsqueeze(0)
            token_id = next_token_id.item()

            if token_id == tokenizer.eos_token_id:
                break

            generated_tokens.append(token_id)
            input_token = next_token_id
    
    text = tokenizer.decode(generated_tokens, skip_special_tokens=True)
    return text

# Exemple d'inférence
if len(val_ids) > 0:
    sample_id = val_ids[0]
    gen_text = generate_sentence_decoder(model_decoder, sample_id, max_len=50)
    print(f"\nExemple génération (motion {sample_id}):\n{gen_text}")
# Out:
# <ipython-input-40-b5711126feb2>:123: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   encoder.load_state_dict(torch.load("motion_encoder.pth", map_location=device))
# 🚀 Début de l'entraînement (avec validation) ...
# Epoch 1/20 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.31it/s, loss=5.5538]
# Epoch 1/20 | Train Loss: 5.5538 | Val Loss: 5.0214
# Epoch 2/20 [Train]: 100%|██████████| 814/814 [01:34<00:00,  8.60it/s, loss=4.7445]
# Epoch 2/20 | Train Loss: 4.7445 | Val Loss: 4.4503
# Epoch 3/20 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.55it/s, loss=4.2019]
# Epoch 3/20 | Train Loss: 4.2019 | Val Loss: 4.0218
# Epoch 4/20 [Train]: 100%|██████████| 814/814 [01:34<00:00,  8.60it/s, loss=3.8952]
# Epoch 4/20 | Train Loss: 3.8952 | Val Loss: 3.8085
# Epoch 5/20 [Train]: 100%|██████████| 814/814 [01:34<00:00,  8.60it/s, loss=3.7038]
# Epoch 5/20 | Train Loss: 3.7038 | Val Loss: 3.6289
# Epoch 6/20 [Train]: 100%|██████████| 814/814 [01:34<00:00,  8.61it/s, loss=3.5546]
# Epoch 6/20 | Train Loss: 3.5546 | Val Loss: 3.4970
# Epoch 7/20 [Train]: 100%|██████████| 814/814 [01:36<00:00,  8.39it/s, loss=3.4131]
# Epoch 7/20 | Train Loss: 3.4131 | Val Loss: 3.3877
# Epoch 8/20 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.49it/s, loss=3.3140]
# Epoch 8/20 | Train Loss: 3.3140 | Val Loss: 3.3077
# Epoch 9/20 [Train]: 100%|██████████| 814/814 [01:36<00:00,  8.48it/s, loss=3.2193]
# Epoch 9/20 | Train Loss: 3.2193 | Val Loss: 3.2191
# Epoch 10/20 [Train]: 100%|██████████| 814/814 [01:35<00:00,  8.52it/s, loss=3.1380]
# Epoch 10/20 | Train Loss: 3.1380 | Val Loss: 3.1849
# Epoch 11/20 [Train]: 100%|██████████| 814/814 [01:36<00:00,  8.47it/s, loss=3.0675]
# Epoch 11/20 | Train Loss: 3.0675 | Val Loss: 3.1111
# Epoch 12/20 [Train]: 100%|██████████| 814/814 [01:36<00:00,  8.43it/s, loss=3.0169]
# Epoch 12/20 | Train Loss: 3.0169 | Val Loss: 3.0224
# Epoch 13/20 [Train]: 100%|██████████| 814/814 [01:37<00:00,  8.36it/s, loss=2.9518]
# Epoch 13/20 | Train Loss: 2.9518 | Val Loss: 3.0352
# Epoch 14/20 [Train]: 100%|██████████| 814/814 [01:41<00:00,  8.03it/s, loss=2.9052]
# Epoch 14/20 | Train Loss: 2.9052 | Val Loss: 2.9634
# Epoch 15/20 [Train]: 100%|██████████| 814/814 [01:40<00:00,  8.11it/s, loss=2.8492]
# Epoch 15/20 | Train Loss: 2.8492 | Val Loss: 2.9426
# Epoch 16/20 [Train]:  27%|██▋       | 220/814 [00:26<01:11,  8.25it/s, loss=2.7949]
